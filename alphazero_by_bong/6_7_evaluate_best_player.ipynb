# %% [markdown]
# # 베스트 플레이어 평가
#
# - 실제 성능은 어떤지 평가해보자
# - 방법
#   - 베스트 플레이어 vs 미니맥스법
#   - 베스트 플레이어 vs 알파베타법
#   - 베스트 플레이어 vs 몬타카를로 트리 탐색
#   - 승률을 표시하여 실제로 강해졌는지 확인

# %%
# evaluate_best_player.py 업로드
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-47c9e702-4384-4c90-b8d6-2640794849ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47c9e702-4384-4c90-b8d6-2640794849ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3ec6c2e99715> in <module>()
#       1 # evaluate_best_player.py 업로드
#       2 from google.colab import files
# ----> 3 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 폴더 확인
# !dir
# Out:
# data			 evaluate_network.py  pv_mcts.py   self_play.py
# dual_network.py		 game.py	      __pycache__  train_network.py
# evaluate_best_player.py  model		      sample_data

# %%
# evaluate_best_player.py 동작 확인
# !python evaluate_best_player.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0728 09:30:06.931492 140185888495488 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0728 09:30:06.931897 140185888495488 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
